# %% [markdown]
# # Uploading Image Data Repository Bioimaging datasets to Hugging Face

# %% [markdown]
# This notebook workflow demonstrates how to reformat a Bioimaging Dataset from Image Data Repository for Hugging Face compliance.

# %% [markdown]
# ## Data download

# %% [markdown]
# ### List all Zarr files in the given dataset
# First, obtain the dataset S3 path by clicking on a single well in the IDR web interface, and selecting "Show filepaths..." in the right thumbnail:
#
#  ![image.png](images/image1.png)

# %%
import bioimageaipub as bp
from pathlib import Path

bp.list_available_data_s3(endpoint_url="https://uk1s3.embassy.ebi.ac.uk", data_dir="s3://bia-integrator-data/S-BIAD845/", file_type=".zarr")
# Out:
# ['bia-integrator-data/S-BIAD845/009bd3ab-eb79-4cf4-8a11-ad028b827c03/009bd3ab-eb79-4cf4-8a11-ad028b827c03.zarr',
#  'bia-integrator-data/S-BIAD845/016aec49-1db4-4f7e-a134-6accf678b0da/016aec49-1db4-4f7e-a134-6accf678b0da.zarr',
#  'bia-integrator-data/S-BIAD845/032164c1-bad8-43c0-9f08-842c5fc12665/032164c1-bad8-43c0-9f08-842c5fc12665.zarr',
#  'bia-integrator-data/S-BIAD845/0414c2c6-9c98-4d8e-832b-e0a626586b60/0414c2c6-9c98-4d8e-832b-e0a626586b60.zarr',
#  'bia-integrator-data/S-BIAD845/041afe9e-e15c-406f-83d3-1f46d5260b61/041afe9e-e15c-406f-83d3-1f46d5260b61.zarr',
#  'bia-integrator-data/S-BIAD845/08568419-fdb4-4f4d-a00f-c9f9c0f74713/08568419-fdb4-4f4d-a00f-c9f9c0f74713.zarr',
#  'bia-integrator-data/S-BIAD845/0869dc84-bcb6-4392-af3f-0f9764a5a1bb/0869dc84-bcb6-4392-af3f-0f9764a5a1bb.zarr',
#  'bia-integrator-data/S-BIAD845/09d35e01-6ba8-467d-9e35-517f05510a1d/09d35e01-6ba8-467d-9e35-517f05510a1d.zarr',
#  'bia-integrator-data/S-BIAD845/0e7a70c5-664f-4b77-b981-cc3ee3120545/0e7a70c5-664f-4b77-b981-cc3ee3120545.zarr',
#  'bia-integrator-data/S-BIAD845/17dc88bf-40d7-4deb-b76a-abe3cbb43ef7/17dc88bf-40d7-4deb-b76a-abe3cbb43ef7.zarr',
#  'bia-integrator-data/S-BIAD845/224c1b34-bfc9-42c2-9b2a-a403be3214ab/224c1b34-bfc9-42c2-9b2a-a403be3214ab.zarr',
#  'bia-integrator-data/S-BIAD845/237399c6-ccb7-4011-8198-1df9ace76d5c/237399c6-ccb7-4011-8198-1df9ace76d5c.zarr',
#  'bia-integrator-data/S-BIAD845/2e14ae61-b7ec-4e04-b974-0a2e7d2c9607/2e14ae61-b7ec-4e04-b974-0a2e7d2c9607.zarr',
#  'bia-integrator-data/S-BIAD845/2f37fe06-c5bc-437a-acc5-b259fe9b0801/2f37fe06-c5bc-437a-acc5-b259fe9b0801.zarr',
#  'bia-integrator-data/S-BIAD845/2fcd7861-a1e3-4f9d-a39c-e33caa96d8ac/2fcd7861-a1e3-4f9d-a39c-e33caa96d8ac.zarr',
#  'bia-integrator-data/S-BIAD845/309c1f32-071f-447f-ad86-065c3c939bc0/309c1f32-071f-447f-ad86-065c3c939bc0.zarr',
#  'bia-integrator-data/S-BIAD845/3130b837-76ed-48ca-bad4-7d76bbd2d86b/3130b837-76ed-48ca-bad4-7d76bbd2d86b.zarr',
#  'bia-integrator-data/S-BIAD845/344e18b1-6ef3-4db5-a5b4-d58538dea080/344e18b1-6ef3-4db5-a5b4-d58538dea080.zarr',
#  'bia-integrator-data/S-BIAD845/37fda0f9-b32e-44f8-b2ad-072a2b3b9460/37fda0f9-b32e-44f8-b2ad-072a2b3b9460.zarr',
#  'bia-integrator-data/S-BIAD845/409227a9-2f3f-421c-8086-b14253283e42/409227a9-2f3f-421c-8086-b14253283e42.zarr',
#  'bia-integrator-data/S-BIAD845/44cb6b70-cea7-4fd2-927b-f45c2e2eb229/44cb6b70-cea7-4fd2-927b-f45c2e2eb229.zarr',
#  'bia-integrator-data/S-BIAD845/49972dd7-a1d4-4b0e-ad85-3ac2651c4201/49972dd7-a1d4-4b0e-ad85-3ac2651c4201.zarr',
#  'bia-integrator-data/S-BIAD845/4a433d93-4946-4d31-a41f-ba6ed95f95bf/4a433d93-4946-4d31-a41f-ba6ed95f95bf.zarr',
#  'bia-integrator-data/S-BIAD845/4f9c4896-adb3-44fa-963c-2bed304fe74b/4f9c4896-adb3-44fa-963c-2bed304fe74b.zarr',
#  'bia-integrator-data/S-BIAD845/528efe2c-b6cd-4c90-bd18-7c901023da8c/528efe2c-b6cd-4c90-bd18-7c901023da8c.zarr',
#  'bia-integrator-data/S-BIAD845/5333d605-4ce4-4628-b2e3-0fe58418aad4/5333d605-4ce4-4628-b2e3-0fe58418aad4.zarr',
#  'bia-integrator-data/S-BIAD845/5394be4d-0d27-4d07-949d-a297cbf414e9/5394be4d-0d27-4d07-949d-a297cbf414e9.zarr',
#  'bia-integrator-data/S-BIAD845/5460c81f-0375-4ac4-895a-40623d0a0ab8/5460c81f-0375-4ac4-895a-40623d0a0ab8.zarr',
#  'bia-integrator-data/S-BIAD845/597162a4-906a-4db7-877e-8aff486aa302/597162a4-906a-4db7-877e-8aff486aa302.zarr',
#  'bia-integrator-data/S-BIAD845/62fbe050-b9a3-4ed5-be14-7d2858af84e1/62fbe050-b9a3-4ed5-be14-7d2858af84e1.zarr',
#  'bia-integrator-data/S-BIAD845/6dc76520-56df-4044-a2c4-7df36c6c1e4b/6dc76520-56df-4044-a2c4-7df36c6c1e4b.zarr',
#  'bia-integrator-data/S-BIAD845/777ab5da-fdab-47dd-9212-7694d3b416b4/777ab5da-fdab-47dd-9212-7694d3b416b4.zarr',
#  'bia-integrator-data/S-BIAD845/78ea1f1a-b887-464d-85f9-322529e8d29d/78ea1f1a-b887-464d-85f9-322529e8d29d.zarr',
#  'bia-integrator-data/S-BIAD845/796b9fb8-f4ec-4c4b-bfc3-5cb00ccf19fe/796b9fb8-f4ec-4c4b-bfc3-5cb00ccf19fe.zarr',
#  'bia-integrator-data/S-BIAD845/7c9dbb28-59c1-4827-ad5d-c5eb59b461ed/7c9dbb28-59c1-4827-ad5d-c5eb59b461ed.zarr',
#  'bia-integrator-data/S-BIAD845/86656b93-0084-4b60-a6f5-a563e226c0e6/86656b93-0084-4b60-a6f5-a563e226c0e6.zarr',
#  'bia-integrator-data/S-BIAD845/87007650-d2bc-48bc-978f-a80f5f27db76/87007650-d2bc-48bc-978f-a80f5f27db76.zarr',
#  'bia-integrator-data/S-BIAD845/8d264931-da76-4389-aea7-d46aac1c1958/8d264931-da76-4389-aea7-d46aac1c1958.zarr',
#  'bia-integrator-data/S-BIAD845/8fc21b53-65f3-4991-810b-dadc7554b807/8fc21b53-65f3-4991-810b-dadc7554b807.zarr',
#  'bia-integrator-data/S-BIAD845/92af8d31-ef51-42ee-89a0-8bbc68412697/92af8d31-ef51-42ee-89a0-8bbc68412697.zarr',
#  'bia-integrator-data/S-BIAD845/94d8197b-7801-481b-a7bb-43409d6c8c00/94d8197b-7801-481b-a7bb-43409d6c8c00.zarr',
#  'bia-integrator-data/S-BIAD845/969f32e1-c209-43e6-b9ac-b51d3cec2cbf/969f32e1-c209-43e6-b9ac-b51d3cec2cbf.zarr',
#  'bia-integrator-data/S-BIAD845/96b2a23a-bf97-4fdf-8be4-28626c379eac/96b2a23a-bf97-4fdf-8be4-28626c379eac.zarr',
#  'bia-integrator-data/S-BIAD845/99d6f37b-c865-4f2a-9314-18290de9cc2f/99d6f37b-c865-4f2a-9314-18290de9cc2f.zarr',
#  'bia-integrator-data/S-BIAD845/9c37fb7a-3752-4d7b-aeb3-d70ab4465eb1/9c37fb7a-3752-4d7b-aeb3-d70ab4465eb1.zarr',
#  'bia-integrator-data/S-BIAD845/9ddfb371-0290-4fe3-a35c-7264c77d5a8d/9ddfb371-0290-4fe3-a35c-7264c77d5a8d.zarr',
#  'bia-integrator-data/S-BIAD845/9fcf99ac-b198-4b54-8cc1-14457995028d/9fcf99ac-b198-4b54-8cc1-14457995028d.zarr',
#  'bia-integrator-data/S-BIAD845/a21eec4a-3b5e-401e-bc5d-cc192a27116d/a21eec4a-3b5e-401e-bc5d-cc192a27116d.zarr',
#  'bia-integrator-data/S-BIAD845/a2bd9f94-0cb2-4cc5-96e8-f4c4dd956c72/a2bd9f94-0cb2-4cc5-96e8-f4c4dd956c72.zarr',
#  'bia-integrator-data/S-BIAD845/ad943bfc-b4c8-4d9b-aea2-4032b84d2a81/ad943bfc-b4c8-4d9b-aea2-4032b84d2a81.zarr',
#  'bia-integrator-data/S-BIAD845/ba253bc9-c216-4116-b4d2-d2f83447e0ae/ba253bc9-c216-4116-b4d2-d2f83447e0ae.zarr',
#  'bia-integrator-data/S-BIAD845/bb83d075-6df1-40fa-a054-5f80be864a94/bb83d075-6df1-40fa-a054-5f80be864a94.zarr',
#  'bia-integrator-data/S-BIAD845/c7ff2b97-6090-47be-b304-13db9f797179/c7ff2b97-6090-47be-b304-13db9f797179.zarr',
#  'bia-integrator-data/S-BIAD845/c872cae5-7962-4877-a176-26c8f9c81d11/c872cae5-7962-4877-a176-26c8f9c81d11.zarr',
#  'bia-integrator-data/S-BIAD845/cbf5602f-74fe-48a8-8b54-9191e98c7893/cbf5602f-74fe-48a8-8b54-9191e98c7893.zarr',
#  'bia-integrator-data/S-BIAD845/cc342401-5d31-425a-98ac-ede49cee0d4c/cc342401-5d31-425a-98ac-ede49cee0d4c.zarr',
#  'bia-integrator-data/S-BIAD845/ce2b2330-9168-46f1-a67f-0681dc01d12d/ce2b2330-9168-46f1-a67f-0681dc01d12d.zarr',
#  'bia-integrator-data/S-BIAD845/d256151a-18c9-4d03-a7f5-1c072f82461e/d256151a-18c9-4d03-a7f5-1c072f82461e.zarr',
#  'bia-integrator-data/S-BIAD845/d7544868-c20c-4447-9783-bd2120d36862/d7544868-c20c-4447-9783-bd2120d36862.zarr',
#  'bia-integrator-data/S-BIAD845/e06368de-ac3c-46f0-a268-687c1e626136/e06368de-ac3c-46f0-a268-687c1e626136.zarr',
#  'bia-integrator-data/S-BIAD845/e3b08a1b-b587-470d-a250-3aae30db634e/e3b08a1b-b587-470d-a250-3aae30db634e.zarr',
#  'bia-integrator-data/S-BIAD845/e5024e45-9721-40fb-81d3-ded71a21c577/e5024e45-9721-40fb-81d3-ded71a21c577.zarr',
#  'bia-integrator-data/S-BIAD845/efa19e04-e0e3-4fc0-8464-fc00e38daf0e/efa19e04-e0e3-4fc0-8464-fc00e38daf0e.zarr',
#  'bia-integrator-data/S-BIAD845/efd73586-3368-420e-9ae1-70dfe1f1efc1/efd73586-3368-420e-9ae1-70dfe1f1efc1.zarr',
#  'bia-integrator-data/S-BIAD845/f083a810-ca3d-404b-b669-ba38ad3099c1/f083a810-ca3d-404b-b669-ba38ad3099c1.zarr',
#  'bia-integrator-data/S-BIAD845/f3af519a-13a1-4bcd-8be2-b6162cf4f950/f3af519a-13a1-4bcd-8be2-b6162cf4f950.zarr',
#  'bia-integrator-data/S-BIAD845/f9e6a854-a29d-4469-9bfb-542724483298/f9e6a854-a29d-4469-9bfb-542724483298.zarr',
#  'bia-integrator-data/S-BIAD845/fa71a2b4-c90b-49fd-a18d-ce3afcb6927a/fa71a2b4-c90b-49fd-a18d-ce3afcb6927a.zarr']

# %% [markdown]
# #### Download the actual Zarrs
#
# You can change to to_download_zarrs.txt to specify which exact Zarrs to download (for low memory settings)

# %%
#!/bin/bash
bp.download_zarrs_from_s3(path="data/idr_zarrs", list_path="../example-data/to_download_zarrs.txt")

# %% [markdown]
# ## Image format conversion
#
# Here, we convert the raw image data to a more accessible format for the wider AI community. Recommended formats are 16-bit PNG and TIFF.

# %%
bp.convert_zarr(root_data_path=Path("data/idr_zarrs"), converted_data_path=Path("data/idr_converted"), zarr_file_list="example-data/to_download_zarrs.txt", output_format="png")

# %% [markdown]
# ### Reformat the dataset as Imagefolder
# https://huggingface.co/docs/datasets/image_dataset

# %%
train_split_ratio = 0.8

bp.test_train_split(converted_data_path=Path("data/idr_converted"), train_ratio=train_split_ratio)
bp.split_into_folders(target=Path("data/idr_converted/test"), max_files=10000)
bp.split_into_folders(target=Path("data/idr_converted/train"), max_files=10000)

# %% [markdown]
# ## Image-level metadata annotation

# %% [markdown]
# #### Import and harmonize metadata from IDR

# %% [markdown]
# The unique advantage of IDR is the high quality annotation it provides. In following, we download the annotation as a data table from additional source.

# %%
anno = bp.fetch_idr_annotation(study_id="idr0012")
# Out:
# /tmp/ipykernel_11922/634179207.py:2: DtypeWarning: Columns (12,50,51,52,90,91,92) have mixed types. Specify dtype option on import or set low_memory=False.
#   anno = pd.read_csv("https://raw.githubusercontent.com/IDR/idr0012-fuchs-cellmorph/700788ee94c21e35b0d614845159e780440772ca/screenA/idr0012-screenA-annotation.csv", sep = ",")

# %%
anno
# Out:
#       Plate  Well Number Well Plate_Well Characteristics [Organism]  \
# 0      HT01            1   A1    HT01_A1                        NaN
# 1      HT01            2   A2    HT01_A2                        NaN
# 2      HT01            3   A3    HT01_A3                        NaN
# 3      HT01            4   A4    HT01_A4               Homo sapiens
# 4      HT01            5   A5    HT01_A5               Homo sapiens
# ...     ...          ...  ...        ...                        ...
# 26107  HT68          380  P20   HT68_P20                        NaN
# 26108  HT68          381  P21   HT68_P21                        NaN
# 26109  HT68          382  P22   HT68_P22                        NaN
# 26110  HT68          383  P23   HT68_P23                        NaN
# 26111  HT68          384  P24   HT68_P24                        NaN
#
#       Term Source 1 REF Term Source 1 Accession Characteristics [Cell Line]  \
# 0                   NaN                     NaN                         NaN
# 1                   NaN                     NaN                         NaN
# 2                   NaN                     NaN                         NaN
# 3             NCBITaxon          NCBITaxon_9606                        HeLa
# 4             NCBITaxon          NCBITaxon_9606                        HeLa
# ...                 ...                     ...                         ...
# 26107               NaN                     NaN                         NaN
# 26108               NaN                     NaN                         NaN
# 26109               NaN                     NaN                         NaN
# 26110               NaN                     NaN                         NaN
# 26111               NaN                     NaN                         NaN
#
#       Term Source 2 REF Term Source 2 Accession  ...  \
# 0                   NaN                     NaN  ...
# 1                   NaN                     NaN  ...
# 2                   NaN                     NaN  ...
# 3                   EFO             EFO_0001185  ...
# 4                   EFO             EFO_0001185  ...
# ...                 ...                     ...  ...
# 26107               NaN                     NaN  ...
# 26108               NaN                     NaN  ...
# 26109               NaN                     NaN  ...
# 26110               NaN                     NaN  ...
# 26111               NaN                     NaN  ...
#
#       Phenotype 15 Term Accession Phenotype 16 Phenotype 16 Term Name a  \
# 0                             NaN          NaN                      NaN
# 1                             NaN          NaN                      NaN
# 2                             NaN          NaN                      NaN
# 3                             NaN          NaN                      NaN
# 4                             NaN          NaN                      NaN
# ...                           ...          ...                      ...
# 26107                         NaN          NaN                      NaN
# 26108                         NaN          NaN                      NaN
# 26109                         NaN          NaN                      NaN
# 26110                         NaN          NaN                      NaN
# 26111                         NaN          NaN                      NaN
#
#       Phenotype 16 Term Accession a Phenotype 16 Term Name b  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 26107                           NaN                      NaN
# 26108                           NaN                      NaN
# 26109                           NaN                      NaN
# 26110                           NaN                      NaN
# 26111                           NaN                      NaN
#
#        Phenotype 16 Term Accession b  Phenotype 17 Phenotype 17 Term Name  \
# 0                                NaN           NaN                    NaN
# 1                                NaN           NaN                    NaN
# 2                                NaN           NaN                    NaN
# 3                                NaN           NaN                    NaN
# 4                                NaN           NaN                    NaN
# ...                              ...           ...                    ...
# 26107                            NaN           NaN                    NaN
# 26108                            NaN           NaN                    NaN
# 26109                            NaN           NaN                    NaN
# 26110                            NaN           NaN                    NaN
# 26111                            NaN           NaN                    NaN
#
#       Phenotype 17 Term Accession Phenotype 18
# 0                             NaN          NaN
# 1                             NaN          NaN
# 2                             NaN          NaN
# 3                             NaN          NaN
# 4                             NaN          NaN
# ...                           ...          ...
# 26107                         NaN          NaN
# 26108                         NaN          NaN
# 26109                         NaN          NaN
# 26110                         NaN          NaN
# 26111                         NaN          NaN
#
# [26112 rows x 102 columns]

# %%
anno["Plate_Well"].unique()
# Out:
# array(['HT01_A1', 'HT01_A2', 'HT01_A3', ..., 'HT68_P22', 'HT68_P23',
#        'HT68_P24'], shape=(26112,), dtype=object)

# %%
huggingface_df = bp.produce_hf_anno(num_fields=2, anno=anno)
# Out:
#             file_name Plate_Well Plate  Well Number Well  \
# 0       HT01_A1_0.png    HT01_A1  HT01            1   A1
# 1       HT01_A1_1.png    HT01_A1  HT01            1   A1
# 2       HT01_A2_0.png    HT01_A2  HT01            2   A2
# 3       HT01_A2_1.png    HT01_A2  HT01            2   A2
# 4       HT01_A3_0.png    HT01_A3  HT01            3   A3
# ...               ...        ...   ...          ...  ...
# 52219  HT68_P22_1.png   HT68_P22  HT68          382  P22
# 52220  HT68_P23_0.png   HT68_P23  HT68          383  P23
# 52221  HT68_P23_1.png   HT68_P23  HT68          383  P23
# 52222  HT68_P24_0.png   HT68_P24  HT68          384  P24
# 52223  HT68_P24_1.png   HT68_P24  HT68          384  P24
#
#       Characteristics [Organism] Term Source 1 REF Term Source 1 Accession  \
# 0                            NaN               NaN                     NaN
# 1                            NaN               NaN                     NaN
# 2                            NaN               NaN                     NaN
# 3                            NaN               NaN                     NaN
# 4                            NaN               NaN                     NaN
# ...                          ...               ...                     ...
# 52219                        NaN               NaN                     NaN
# 52220                        NaN               NaN                     NaN
# 52221                        NaN               NaN                     NaN
# 52222                        NaN               NaN                     NaN
# 52223                        NaN               NaN                     NaN
#
#       Characteristics [Cell Line] Term Source 2 REF  ...  \
# 0                             NaN               NaN  ...
# 1                             NaN               NaN  ...
# 2                             NaN               NaN  ...
# 3                             NaN               NaN  ...
# 4                             NaN               NaN  ...
# ...                           ...               ...  ...
# 52219                         NaN               NaN  ...
# 52220                         NaN               NaN  ...
# 52221                         NaN               NaN  ...
# 52222                         NaN               NaN  ...
# 52223                         NaN               NaN  ...
#
#       Phenotype 15 Term Accession Phenotype 16 Phenotype 16 Term Name a  \
# 0                             NaN          NaN                      NaN
# 1                             NaN          NaN                      NaN
# 2                             NaN          NaN                      NaN
# 3                             NaN          NaN                      NaN
# 4                             NaN          NaN                      NaN
# ...                           ...          ...                      ...
# 52219                         NaN          NaN                      NaN
# 52220                         NaN          NaN                      NaN
# 52221                         NaN          NaN                      NaN
# 52222                         NaN          NaN                      NaN
# 52223                         NaN          NaN                      NaN
#
#       Phenotype 16 Term Accession a Phenotype 16 Term Name b  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 52219                           NaN                      NaN
# 52220                           NaN                      NaN
# 52221                           NaN                      NaN
# 52222                           NaN                      NaN
# 52223                           NaN                      NaN
#
#       Phenotype 16 Term Accession b  Phenotype 17  Phenotype 17 Term Name  \
# 0                               NaN           NaN                     NaN
# 1                               NaN           NaN                     NaN
# 2                               NaN           NaN                     NaN
# 3                               NaN           NaN                     NaN
# 4                               NaN           NaN                     NaN
# ...                             ...           ...                     ...
# 52219                           NaN           NaN                     NaN
# 52220                           NaN           NaN                     NaN
# 52221                           NaN           NaN                     NaN
# 52222                           NaN           NaN                     NaN
# 52223                           NaN           NaN                     NaN
#
#       Phenotype 17 Term Accession Phenotype 18
# 0                             NaN          NaN
# 1                             NaN          NaN
# 2                             NaN          NaN
# 3                             NaN          NaN
# 4                             NaN          NaN
# ...                           ...          ...
# 52219                         NaN          NaN
# 52220                         NaN          NaN
# 52221                         NaN          NaN
# 52222                         NaN          NaN
# 52223                         NaN          NaN
#
# [52224 rows x 103 columns]

# %% [markdown]
# ### Add OMExcavator metadata

# %% [markdown]
# [OMExcavator](https://codebase.helmholtz.cloud/stefan.dvoretskii/omero-crawler) is a tool to extract OMERO image metadata in an interoperable JSON-LD format. We will use it here to extract metadata fields which are provided in the OMERO annotation on top of those in the official CSV - mostly technical metadata related to imaging.

# %%
bp.fetch_omero_metadata(omexcavator_path="c:\src\omexcavator")
# Out:
#   Cell In[9], line 1
#     git clone https://codebase.helmholtz.cloud/stefan.dvoretskii/omero-crawler.git
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Fetching metadata is a heavy process currently, and can take around 14 hours for a dataset of 55,000 images.

# %%
## Parse a single OMExcavator JSON file to see what metadata fields are available
import json
with open("../example-data/image-1811248-well-1000475-plate-4287-screen-1202.jsonld", "r") as f:
    omexcavator_metadata = json.load(f)

# %%
for ann_obj in omexcavator_metadata["image"]["Annotations"]:
    print(ann_obj["@type"], ":", ann_obj["Value"])
# Out:
# http://www.openmicroscopy.org/Schemas/OME/2016-06#MapAnnotation : [['siRNA Identifier', 'D-003255-06'], ['siRNA Identifier', 'D-003255-07'], ['siRNA Identifier', 'D-003255-08'], ['siRNA Identifier', 'D-003255-09'], ['siRNA Pool Identifier', 'M-003255-02']]
# http://www.openmicroscopy.org/Schemas/OME/2016-06#MapAnnotation : [['Original GeneID Target', '1111'], ['Original Gene Target', 'CHEK1'], ['Original RefSeq Target', 'NM_001274'], ['Original LocusLink Target', '20127419']]
# http://www.openmicroscopy.org/Schemas/OME/2016-06#MapAnnotation : [['RefSeq Accession', 'NM_001274'], ['RefSeq Hits', '4'], ['Analysis Gene Annotation Build', 'NCBI36.3, RefSeq release 27, Jan 2008']]
# http://www.openmicroscopy.org/Schemas/OME/2016-06#MapAnnotation : [['Organism', 'Homo sapiens']]
# http://www.openmicroscopy.org/Schemas/OME/2016-06#MapAnnotation : [['Channels', 'Alexa 488:tubulin;Hoechst:DNA;Tritc:actin']]
# http://www.openmicroscopy.org/Schemas/OME/2016-06#MapAnnotation : [['Cell Line', 'HeLa']]
# http://www.openmicroscopy.org/Schemas/OME/2016-06#MapAnnotation : [['Gene Identifier', '1111'], ['Gene Identifier URL', 'https://www.ncbi.nlm.nih.gov/gene/1111'], ['Gene Symbol', 'CHEK1'], ['Gene Identifier URL', 'http://www.ncbi.nlm.nih.gov/gene/1111']]

# %%
idr_anno_collist = anno.columns.tolist()
idr_anno_collist
# Out:
# ['Plate',
#  'Well Number',
#  'Well',
#  'Plate_Well',
#  'Characteristics [Organism]',
#  'Term Source 1 REF',
#  'Term Source 1 Accession',
#  'Characteristics [Cell Line]',
#  'Term Source 2 REF',
#  'Term Source 2 Accession',
#  'siRNA Pool Identifier',
#  'siRNA Identifier',
#  'Original GeneID Target',
#  'Original Gene Target',
#  'Original RefSeq Target',
#  'Original LocusLink Target',
#  'Reagent Design Gene Annotation Build',
#  'Gene Identifier',
#  'Gene Symbol',
#  'RefSeq Accession',
#  'RefSeq Hits',
#  'Gene Annotation Comments',
#  'Analysis Gene Annotation Build',
#  'Control Type',
#  'Control Comments',
#  'Channels',
#  'n',
#  'ext',
#  'ecc',
#  'Ato',
#  'Nex',
#  'Nin',
#  'Nto',
#  'AF',
#  'BC',
#  'C',
#  'M',
#  'LA',
#  'P',
#  'Cluster',
#  'Has Phenotype',
#  'Phenotype Annotation Level',
#  'Phenotype 1',
#  'Phenotype 1 Term Name a',
#  'Phenotype 1 Term Accession a',
#  'Phenotype 1 Term Name b',
#  'Phenotype 1 Term Accession b',
#  'Phenotype 2',
#  'Phenotype 2 Term Name',
#  'Phenotype 2 Term Accession',
#  'Phenotype 3',
#  'Phenotype 3 Term Name',
#  'Phenotype 3 Term Accession',
#  'Phenotype 4',
#  'Phenotype 4 Term Name',
#  'Phenotype 4 Term Accession',
#  'Phenotype 5',
#  'Phenotype 5 Term Name',
#  'Phenotype 5 Term Accession',
#  'Phenotype 6',
#  'Phenotype 6 Term Name a',
#  'Phenotype 6 Term Accession a',
#  'Phenotype 6 Term Name b',
#  'Phenotype 6 Term Accession b',
#  'Phenotype 7',
#  'Phenotype 7 Term Name a',
#  'Phenotype 7 Term Accession a',
#  'Phenotype 7 Term Name b',
#  'Phenotype 7 Term Accession b',
#  'Phenotype 8',
#  'Phenotype 8 Term Name',
#  'Phenotype 8 Term Accession',
#  'Phenotype 9',
#  'Phenotype 9 Term Name',
#  'Phenotype 9 Term Accession',
#  'Phenotype 10',
#  'Phenotype 10 Term Name',
#  'Phenotype 10 Term Accession',
#  'Phenotype 11',
#  'Phenotype 11 Term Name',
#  'Phenotype 11 Term Accession',
#  'Phenotype 12',
#  'Phenotype 12 Term Name',
#  'Phenotype 12 Term Accession',
#  'Phenotype 13',
#  'Phenotype 13 Term Name',
#  'Phenotype 13 Term Accession',
#  'Phenotype 14',
#  'Phenotype 14 Term Name',
#  'Phenotype 14 Term Accession',
#  'Phenotype 15',
#  'Phenotype 15 Term Name',
#  'Phenotype 15 Term Accession',
#  'Phenotype 16',
#  'Phenotype 16 Term Name a',
#  'Phenotype 16 Term Accession a',
#  'Phenotype 16 Term Name b',
#  'Phenotype 16 Term Accession b',
#  'Phenotype 17',
#  'Phenotype 17 Term Name',
#  'Phenotype 17 Term Accession',
#  'Phenotype 18']

# %%
list(filter(lambda x: "Channel" in x, idr_anno_collist))
# Out:
# ['Channels']

# %% [markdown]
# Looks like all the Image Annotations are in the IDR table annotation already (**might be different for other datasets!**). However, the IDR annotation does not contain Physical Size of images, and also the channel colors.

# %%
list(filter(lambda x: "Size" in x, idr_anno_collist))
# Out:
# []

# %%
## Add physical size metadata to the huggingface dataframe
huggingface_df["PhysicalSizeX"] = f'{omexcavator_metadata["image"]["Pixels"]["PhysicalSizeX"]["Value"]} {omexcavator_metadata["image"]["Pixels"]["PhysicalSizeX"]["Unit"]}'
huggingface_df["PhysicalSizeY"] = f'{omexcavator_metadata["image"]["Pixels"]["PhysicalSizeY"]["Value"]} {omexcavator_metadata["image"]["Pixels"]["PhysicalSizeY"]["Unit"]}'

# %%
huggingface_df["Channel_Color"] = "; ".join([f"{i}: {chan['Color']}" for i, chan in enumerate(omexcavator_metadata["channels"])])

# %%
huggingface_df
# Out:
#             file_name Plate_Well Plate  Well Number Well  \
# 0       HT01_A1_0.png    HT01_A1  HT01            1   A1
# 1       HT01_A1_1.png    HT01_A1  HT01            1   A1
# 2       HT01_A2_0.png    HT01_A2  HT01            2   A2
# 3       HT01_A2_1.png    HT01_A2  HT01            2   A2
# 4       HT01_A3_0.png    HT01_A3  HT01            3   A3
# ...               ...        ...   ...          ...  ...
# 52219  HT68_P22_1.png   HT68_P22  HT68          382  P22
# 52220  HT68_P23_0.png   HT68_P23  HT68          383  P23
# 52221  HT68_P23_1.png   HT68_P23  HT68          383  P23
# 52222  HT68_P24_0.png   HT68_P24  HT68          384  P24
# 52223  HT68_P24_1.png   HT68_P24  HT68          384  P24
#
#       Characteristics [Organism] Term Source 1 REF Term Source 1 Accession  \
# 0                            NaN               NaN                     NaN
# 1                            NaN               NaN                     NaN
# 2                            NaN               NaN                     NaN
# 3                            NaN               NaN                     NaN
# 4                            NaN               NaN                     NaN
# ...                          ...               ...                     ...
# 52219                        NaN               NaN                     NaN
# 52220                        NaN               NaN                     NaN
# 52221                        NaN               NaN                     NaN
# 52222                        NaN               NaN                     NaN
# 52223                        NaN               NaN                     NaN
#
#       Characteristics [Cell Line] Term Source 2 REF  ...  \
# 0                             NaN               NaN  ...
# 1                             NaN               NaN  ...
# 2                             NaN               NaN  ...
# 3                             NaN               NaN  ...
# 4                             NaN               NaN  ...
# ...                           ...               ...  ...
# 52219                         NaN               NaN  ...
# 52220                         NaN               NaN  ...
# 52221                         NaN               NaN  ...
# 52222                         NaN               NaN  ...
# 52223                         NaN               NaN  ...
#
#       Phenotype 16 Term Accession a Phenotype 16 Term Name b  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 52219                           NaN                      NaN
# 52220                           NaN                      NaN
# 52221                           NaN                      NaN
# 52222                           NaN                      NaN
# 52223                           NaN                      NaN
#
#       Phenotype 16 Term Accession b Phenotype 17 Phenotype 17 Term Name  \
# 0                               NaN          NaN                    NaN
# 1                               NaN          NaN                    NaN
# 2                               NaN          NaN                    NaN
# 3                               NaN          NaN                    NaN
# 4                               NaN          NaN                    NaN
# ...                             ...          ...                    ...
# 52219                           NaN          NaN                    NaN
# 52220                           NaN          NaN                    NaN
# 52221                           NaN          NaN                    NaN
# 52222                           NaN          NaN                    NaN
# 52223                           NaN          NaN                    NaN
#
#       Phenotype 17 Term Accession  Phenotype 18                 PhysicalSizeX  \
# 0                             NaN           NaN  338.6666666666667 MICROMETER
# 1                             NaN           NaN  338.6666666666667 MICROMETER
# 2                             NaN           NaN  338.6666666666667 MICROMETER
# 3                             NaN           NaN  338.6666666666667 MICROMETER
# 4                             NaN           NaN  338.6666666666667 MICROMETER
# ...                           ...           ...                           ...
# 52219                         NaN           NaN  338.6666666666667 MICROMETER
# 52220                         NaN           NaN  338.6666666666667 MICROMETER
# 52221                         NaN           NaN  338.6666666666667 MICROMETER
# 52222                         NaN           NaN  338.6666666666667 MICROMETER
# 52223                         NaN           NaN  338.6666666666667 MICROMETER
#
#                       PhysicalSizeY                        Channel_Color
# 0      338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 1      338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 2      338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 3      338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 4      338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# ...                             ...                                  ...
# 52219  338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 52220  338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 52221  338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 52222  338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
# 52223  338.6666666666667 MICROMETER  0: -16776961; 1: 16711935; 2: 65535
#
# [52224 rows x 106 columns]

# %%
bp.save_hf_anno(huggingface_df, converted_data_path="data/idr_converted", split_folder="all", mixed_data_type_columns=["Original GeneID Target"])

# %% [markdown]
# ### Test conversion to PyArrow
#
# That's what HuggingFace uses to build dataset preview
#
# ![image.png](images/image2.png)
#
# See https://discuss.huggingface.co/t/dataset-preview-pyarrow-lib-arrowtypeerror-expected-bytes-got-a-float-object/169874 for the bug description. I check the tables locally, and remove the problematic mixed dtype columns (sacrificing metadata, which is sad)

# %%
import pyarrow as pa
converted_data_path="data/idr_converted"
df = pd.read_csv(f"{converted_data_path}/metadata/metadata.csv")
pat = pa.Table.from_pandas(df)
# Out:
# /tmp/ipykernel_11922/2659909305.py:2: DtypeWarning: Columns (50,51,52,90,91,92) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{converted_data_path}/metadata/metadata.csv")

# %%
import os 
import pandas as pd

for splitdir in os.listdir(converted_data_path / "train"):
    if os.path.isdir(os.path.join(converted_data_path, "train", splitdir)):
        bp.save_hf_anno(huggingface_df, converted_data_path="data/idr_converted", split_folder=f"train/{splitdir}", mixed_data_type_columns=["Cluster"])

# %%
import pyarrow as pa
for i in range(1,5):
    df = pd.read_csv(f"{converted_data_path}/train{i}/metadata.csv")
    
    pat = pa.Table.from_pandas(df)
# Out:
# /tmp/ipykernel_11922/2464966945.py:3: DtypeWarning: Columns (86,87,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{converted_data_path}/train{i}/metadata.csv")

# %%
test_images = []
for image_fname in os.listdir(f"{converted_data_path}/test/"):
    test_images.append(image_fname)
    
test_huggingface_anno = pd.merge(pd.Series(test_images, name = "file_name"), huggingface_df, how="left")
test_huggingface_anno
# Out:
#            file_name Plate_Well Plate  Well Number Well  \
# 0     HT60_F21_1.png   HT60_F21  HT60        141.0  F21
# 1     HT53_O10_0.png   HT53_O10  HT53        346.0  O10
# 2     HT30_I23_1.png   HT30_I23  HT30        215.0  I23
# 3     HT47_K19_0.png   HT47_K19  HT47        259.0  K19
# 4     HT25_O18_1.png   HT25_O18  HT25        354.0  O18
# ...              ...        ...   ...          ...  ...
# 9263   HT24_P9_0.png    HT24_P9  HT24        369.0   P9
# 9264  HT37_C13_0.png   HT37_C13  HT37         61.0  C13
# 9265   HT44_O9_1.png    HT44_O9  HT44        345.0   O9
# 9266  HT55_L24_0.png   HT55_L24  HT55        288.0  L24
# 9267  HT38_K19_1.png   HT38_K19  HT38        259.0  K19
#
#      Characteristics [Organism] Term Source 1 REF Term Source 1 Accession  \
# 0                  Homo sapiens         NCBITaxon          NCBITaxon_9606
# 1                  Homo sapiens         NCBITaxon          NCBITaxon_9606
# 2                  Homo sapiens         NCBITaxon          NCBITaxon_9606
# 3                  Homo sapiens         NCBITaxon          NCBITaxon_9606
# 4                  Homo sapiens         NCBITaxon          NCBITaxon_9606
# ...                         ...               ...                     ...
# 9263               Homo sapiens         NCBITaxon          NCBITaxon_9606
# 9264               Homo sapiens         NCBITaxon          NCBITaxon_9606
# 9265               Homo sapiens         NCBITaxon          NCBITaxon_9606
# 9266               Homo sapiens         NCBITaxon          NCBITaxon_9606
# 9267               Homo sapiens         NCBITaxon          NCBITaxon_9606
#
#      Characteristics [Cell Line] Term Source 2 REF  ...  \
# 0                           HeLa               EFO  ...
# 1                           HeLa               EFO  ...
# 2                           HeLa               EFO  ...
# 3                           HeLa               EFO  ...
# 4                           HeLa               EFO  ...
# ...                          ...               ...  ...
# 9263                        HeLa               EFO  ...
# 9264                        HeLa               EFO  ...
# 9265                        HeLa               EFO  ...
# 9266                        HeLa               EFO  ...
# 9267                        HeLa               EFO  ...
#
#      Phenotype 16 Term Accession a Phenotype 16 Term Name b  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4                              NaN                      NaN
# ...                            ...                      ...
# 9263                           NaN                      NaN
# 9264                           NaN                      NaN
# 9265                           NaN                      NaN
# 9266                           NaN                      NaN
# 9267                           NaN                      NaN
#
#      Phenotype 16 Term Accession b Phenotype 17 Phenotype 17 Term Name  \
# 0                              NaN          NaN                    NaN
# 1                              NaN          NaN                    NaN
# 2                              NaN          NaN                    NaN
# 3                              NaN          NaN                    NaN
# 4                              NaN          NaN                    NaN
# ...                            ...          ...                    ...
# 9263                           NaN          NaN                    NaN
# 9264                           NaN          NaN                    NaN
# 9265                           NaN          NaN                    NaN
# 9266                           NaN          NaN                    NaN
# 9267                           NaN          NaN                    NaN
#
#       Phenotype 17 Term Accession     Phenotype 18  \
# 0                             NaN              NaN
# 1                             NaN              NaN
# 2                             NaN  other phenotype
# 3                             NaN              NaN
# 4                             NaN              NaN
# ...                           ...              ...
# 9263                          NaN              NaN
# 9264                          NaN              NaN
# 9265                          NaN              NaN
# 9266                          NaN              NaN
# 9267                          NaN              NaN
#
#                      PhysicalSizeX                 PhysicalSizeY  \
# 0     338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 1     338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 2     338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 3     338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 4     338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# ...                            ...                           ...
# 9263  338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 9264  338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 9265  338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 9266  338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
# 9267  338.6666666666667 MICROMETER  338.6666666666667 MICROMETER
#
#                             Channel_Color
# 0     0: -16776961; 1: 16711935; 2: 65535
# 1     0: -16776961; 1: 16711935; 2: 65535
# 2     0: -16776961; 1: 16711935; 2: 65535
# 3     0: -16776961; 1: 16711935; 2: 65535
# 4     0: -16776961; 1: 16711935; 2: 65535
# ...                                   ...
# 9263  0: -16776961; 1: 16711935; 2: 65535
# 9264  0: -16776961; 1: 16711935; 2: 65535
# 9265  0: -16776961; 1: 16711935; 2: 65535
# 9266  0: -16776961; 1: 16711935; 2: 65535
# 9267  0: -16776961; 1: 16711935; 2: 65535
#
# [9268 rows x 105 columns]

# %%
for splitdir in os.listdir(converted_data_path / "test"):
    if os.path.isdir(os.path.join(converted_data_path, "test", splitdir)):
        bp.save_hf_anno(huggingface_df, converted_data_path="data/idr_converted", split_folder=f"test/{splitdir}", mixed_data_type_columns=["Cluster"])
        
df = pd.read_csv(f"{converted_data_path}/test/metadata.csv")
pat = pa.Table.from_pandas(df)
# Out:
# /tmp/ipykernel_11922/8779366.py:5: DtypeWarning: Columns (52,53,54,92,93,94,95,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{converted_data_path}/test/metadata.csv")

# %%
df = pd.read_csv(f"{converted_data_path}/train4/metadata.csv")
pat = pa.Table.from_pandas(df)

# %% [markdown]
# ## Image data upload

# %% [markdown]
# Upload the dataset as a big folder

# %%
destination_dataset = "stefanches/genomic-bioimaging"
converted_folder_path = "/vol/sdb/S-BIAD845-converted/"

bp.hf_upload_converted_folder(converted_folder_path, destination_dataset)
# Out:
# Folder 'train' contains 36,426 entries (36,426 files and 0 subdirectories). This exceeds the recommended 10,000 entries per folder.
# Consider reorganising into sub-folders.
# WARNING:huggingface_hub._upload_large_folder:Folder 'train' contains 36,426 entries (36,426 files and 0 subdirectories). This exceeds the recommended 10,000 entries per folder.
# Consider reorganising into sub-folders.
# Recovering from metadata files: 100%|██████████| 45763/45763 [00:15<00:00, 2885.82it/s]
# ---------- 2025-11-03 14:05:12 (0:00:00) ----------
# Files:   hashed 19/45763 (344.5K/279.7G) | pre-uploaded: 0/0 (0.0/279.7G) (+45763 unsure) | committed: 0/45763 (0.0/279.7G) | ignored: 0
# Workers: hashing: 13 | get upload mode: 1 | pre-uploading: 0 | committing: 0 | waiting: 0
# ---------------------------------------------------
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  386MB/s
# New Data Upload: 100%|██████████| 18.8MB / 18.8MB, 5.21MB/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  489MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  570MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  539MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (57 / 57): 100%|██████████|  361MB /  361MB,  302MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  524MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  534MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  533MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  531MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  461MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  587MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (100 / 100): 100%|██████████|  610MB /  610MB,  254MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  573MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  573MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (125 / 125): 100%|██████████|  766MB /  766MB,  402MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  489MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  552MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  575MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  458MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s  .57GB,  935MB/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  534MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (200 / 200): 100%|██████████| 1.22GB / 1.22GB,  306MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  392MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  461MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  434MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (250 / 250): 100%|██████████| 1.52GB / 1.52GB,  438MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  461MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  491MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  392MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  574MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  326MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (400 / 400): |          | 2.45GB /     ?B,  340MB/s  /s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (74 / 74):  29%|██▉       |  454MB / 1.56GB,  379MB/s
# ---------- 2025-11-03 14:06:12 (0:01:00) ----------
# Files:   hashed 7751/45763 (47.0G/279.7G) | pre-uploaded: 6400/7430 (39.2G/279.7G) (+38265 unsure) | committed: 800/45763 (4.5G/279.7G) | ignored: 0
# Workers: hashing: 6 | get upload mode: 3 | pre-uploading: 4 | committing: 1 | waiting: 0
# ---------------------------------------------------
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  459MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  460MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  392MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  563MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  357MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  342MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  261MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  223MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  392MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  281MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (600 / 600): |          | 3.66GB /     ?B,  103MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  245MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  225MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  231MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (135 / 135):  53%|█████▎    |  825MB / 1.57GB,  258MB/s  Failed to get upload mode: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/preupload/main
# ERROR:huggingface_hub._upload_large_folder:Failed to get upload mode: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/preupload/main
# Failed to get upload mode: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/preupload/main
# ERROR:huggingface_hub._upload_large_folder:Failed to get upload mode: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/preupload/main
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  312MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  314MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  325MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  519MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  605MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  290MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  313MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  244MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.55GB / 1.55GB,  204MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  245MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  174MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  196MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  259MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  230MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  169MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (79 / 79):  31%|███       |  485MB / 1.56GB, 60.6MB/s
# ---------- 2025-11-03 14:07:13 (0:02:01) ----------
# Files:   hashed 15075/45763 (91.8G/279.7G) | pre-uploaded: 13312/14780 (81.5G/279.7G) (+30914 unsure) | committed: 1800/45763 (10.6G/279.7G) | ignored: 0
# Workers: hashing: 6 | get upload mode: 2 | pre-uploading: 5 | committing: 1 | waiting: 0
# ---------------------------------------------------
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  159MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  201MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  195MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  196MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  196MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s  .56GB, 79.4MB/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (49 / 49):  19%|█▉        |  298MB / 1.57GB, 29.2MB/s
# ---------- 2025-11-03 14:08:13 (0:03:01) ----------
# Files:   hashed 21693/45763 (132.3G/279.7G) | pre-uploaded: 19456/21601 (119.0G/279.7G) (+24093 unsure) | committed: 2800/45763 (16.7G/279.7G) | ignored: 0
# Workers: hashing: 4 | get upload mode: 1 | pre-uploading: 8 | committing: 1 | waiting: 0
# ---------------------------------------------------
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.13GB /     ?B,  142MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  157MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  167MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  179MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  187MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  238MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  206MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  212MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  315MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  218MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  187MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  191MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  201MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  179MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  197MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  219MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  224MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  165MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  156MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (177 / 177):  69%|██████▉   | 1.09GB / 1.58GB,  287MB/s
# ---------- 2025-11-03 14:09:13 (0:04:01) ----------
# Files:   hashed 28582/45763 (174.5G/279.7G) | pre-uploaded: 26903/28370 (164.7G/279.7G) (+17324 unsure) | committed: 3800/45763 (22.8G/279.7G) | ignored: 0
# Workers: hashing: 6 | get upload mode: 2 | pre-uploading: 5 | committing: 1 | waiting: 0
# ---------------------------------------------------
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  303MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  302MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  433MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  435MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  313MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  328MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  372MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  393MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  587MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  568MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  569MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  392MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  579MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  567MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  571MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  411MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  279MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  392MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  261MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  253MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  302MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  201MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  232MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  223MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  231MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  165MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  230MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  223MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  271MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  237MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  327MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# ---------- 2025-11-03 14:10:14 (0:05:02) ----------
# Files:   hashed 35924/45763 (219.5G/279.7G) | pre-uploaded: 34561/35684 (211.5G/279.7G) (+10010 unsure) | committed: 4800/45763 (29.0G/279.7G) | ignored: 0
# Workers: hashing: 7 | get upload mode: 2 | pre-uploading: 4 | committing: 1 | waiting: 0
# ---------------------------------------------------
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  435MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  372MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  326MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  342MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  602MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  571MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  574MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  566MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  356MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  338MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  261MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  245MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  312MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  373MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  327MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  215MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  231MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  270MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  270MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  325MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  392MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  489MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.55GB / 1.55GB,  517MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  524MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  572MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.58GB / 1.58GB,  388MB/s
# New Data Upload: 100%|██████████| 14.2MB / 14.2MB, 3.95MB/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  574MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  567MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  391MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (295 / 295): |          | 1.80GB /     ?B, 92.4MB/s  /s
# ---------- 2025-11-03 14:11:15 (0:06:03) ----------
# Files:   hashed 43130/45763 (263.5G/279.7G) | pre-uploaded: 41984/42943 (256.9G/279.7G) (+2751 unsure) | committed: 6800/45763 (41.2G/279.7G) | ignored: 0
# Workers: hashing: 9 | get upload mode: 1 | pre-uploading: 3 | committing: 1 | waiting: 0
# ---------------------------------------------------
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  393MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (110 / 110):  43%|████▎     |  672MB / 1.56GB,  305MB/s  Failed to preupload LFS: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/revision/main?expand=xetEnabled
# ERROR:huggingface_hub._upload_large_folder:Failed to preupload LFS: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/revision/main?expand=xetEnabled
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  270MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  390MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  245MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  224MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  202MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  202MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (999 / 999): |          | 6.12GB /     ?B,  157MB/s  /s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  160MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  192MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  178MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  212MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.57GB / 1.57GB,  212MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (256 / 256): 100%|██████████| 1.56GB / 1.56GB,  290MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (146 / 146): 100%|██████████|  891MB /  891MB,  165MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1 / 1): 100%|██████████| 6.28MB / 6.28MB, 1.12MB/s  /s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1 / 1): 100%|██████████| 5.99MB / 5.99MB, 1.07MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1 / 1): 100%|██████████| 5.97MB / 5.97MB, 1.11MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1 / 1): 100%|██████████| 6.53MB / 6.53MB, 1.17MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (31 / 31): 100%|██████████|  190MB /  190MB, 31.7MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (100 / 100): 100%|██████████|  612MB /  612MB,  204MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1 / 1): 100%|██████████| 6.34MB / 6.34MB, 7.93MB/s  /s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  529MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Failed to get upload mode: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/preupload/main
# ERROR:huggingface_hub._upload_large_folder:Failed to get upload mode: 502 Server Error: Bad Gateway for url: https://huggingface.co/api/datasets/stefanches/genomic-bioimaging/preupload/main
# Processing Files (100 / 100): 100%|██████████|  608MB /  608MB,  320MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (928 / 928): |          | 5.69GB /     ?B,  821MB/s
# ---------- 2025-11-03 14:12:15 (0:07:03) ----------
# Files:   hashed 45763/45763 (279.7G/279.7G) | pre-uploaded: 45694/45694 (279.7G/279.7G) | committed: 8800/45763 (53.5G/279.7G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 0 | committing: 1 | waiting: 13
# ---------------------------------------------------
# Processing Files (1000 / 1000): |          | 6.14GB /     ?B,  527MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.11GB /     ?B,  531MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  525MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# ---------- 2025-11-03 14:13:15 (0:08:03) ----------
# Files:   hashed 45763/45763 (279.7G/279.7G) | pre-uploaded: 45694/45694 (279.7G/279.7G) | committed: 11381/45763 (69.3G/279.7G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 0 | committing: 1 | waiting: 13
# ---------------------------------------------------
# Processing Files (1000 / 1000): |          | 6.11GB /     ?B,  517MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.11GB /     ?B,  530MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  530MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# ---------- 2025-11-03 14:14:16 (0:09:04) ----------
# Files:   hashed 45763/45763 (279.7G/279.7G) | pre-uploaded: 45694/45694 (279.7G/279.7G) | committed: 13800/45763 (84.0G/279.7G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 0 | committing: 1 | waiting: 13
# ---------------------------------------------------
# Processing Files (1000 / 1000): |          | 6.12GB /     ?B,  482MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s

# %% [markdown]
# ## Dataset-level metadata annotation

# %% [markdown]
# To add the dataset details (Dataset Source, License etc.), use the HuggingFace Dataset Card interface:![image.png](images/image3.png)
#
#
#
# For time purposes, the Large  Models assistance can be helpful in filling out the Dataset Card, however these were not used in the test experiments due to the high possibility of errors, and this is in no way encouraged.
# Please, always check the information filled in by Large Language Models in regards to the factuality if you use them.

# %% [markdown]
# This step is manual, and consists of fetching the dataset metadata from the already existing sources. For the Imaging Data Repository datasets, there are ["study" pages](https://idr.openmicroscopy.org/study/idr0012/) which provide useful links to various repositories where additional Dataset-level metadata can be found:
# ![image.png](images/image4.png)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This notebook demonstrates how to upload a Bioimaging study data to HuggingFace, ensuring all the metadata is AI-ready and accessible to users through their favourite Machine Learning framework. Small deviations from the process are possible for diverse datasets, e.g. those hosted on FTP servers instead of S3 buckets.
